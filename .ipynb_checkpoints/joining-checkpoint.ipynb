# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
elev = pd.read_csv("/Users/marthamorrissey/Desktop/DS_practice/stations_elev.csv")

# %%
elev.columns
# Out:
# Index(['Unnamed: 0', 'GID', 'STATION_ID', 'NAME', 'ADDRESS', 'LAT', 'LON',
#        'SOURCE', 'geometry', 'e'],
#       dtype='object')

# %%
elev['LAT'][0]
# Out:
# 40.008109999999995

# %%
elev_small = elev[['NAME', 'e']]

# %%
elev_small.head()
# Out:
#                 NAME            e
# 0  Folsom & Colorado  1634.405396
# 1       15th & Pearl  1628.207275
# 2       11th & Pearl  1633.299438
# 3      13th & Spruce  1631.223511
# 4  UCAR Center Green  1611.138916

# %%
elev_small['NAME_end'] = elev_small['NAME']
# Out:
# //anaconda/envs/snakee/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
elev_small.columns
# Out:
# Index(['NAME', 'e', 'NAME_end'], dtype='object')

# %%
df_full = pd.read_csv('/Users/marthamorrissey/Desktop/DS_practice/bcycle_modified_full.csv')

# %%
df_full_small = df_full.head(10)

# %%
df_full_small
# Out:
#    Unnamed: 0  Unnamed: 0.1  Bike Number  \
# 0           0             1          206
# 1           1            11          733
# 2           2            13          251
# 3           3            14          728
# 4           4            17          243
# 5           5            20          726
# 6           6            24          701
# 7           7            26          520
# 8           8            27          678
# 9           9            28          626
#
#    COUNT([Checkout Station])+COUNT([Return Station]) Checkout Date  \
# 0                                                  2       1/22/17
# 1                                                  2       8/29/16
# 2                                                  2        7/3/15
# 3                                                  2       8/13/17
# 4                                                  2      11/20/15
# 5                                                  2       9/27/14
# ...

# %%
df_full_small.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'Checkout Station (Station Information)',
#        'Checkout Station Latitude1', 'Checkout Station Longitude1',
#        'Checkout Station', 'Checkout Time', 'Entry Pass Type',
#        'Installation Date', 'Most Recent Number of Docks', 'Number of Records',
#        'Power Source', 'Removal Date', 'Return Date', 'Return Day of Week',
#        'Return Station (Station Information)', 'Return Station Latitude',
#        'Return Station Longitude', 'Return Station', 'Return Time',
#        'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation'],
#       dtype='object')

# %%
df_full_small=df_full_small.rename(columns = {'Checkout Station (Station Information)':'NAME'})

# %%
df_full_small.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'Return Station',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation'],
#       dtype='object')

# %%
df_full_small['Return Station']
# Out:
# 0             9th & Pearl
# 1       Broadway & Alpine
# 2         21st & Arapahoe
# 3       Broadway & Alpine
# 4          Settlers' Park
# 5     Broadway & Baseline
# 6        Williams Village
# 7        Williams Village
# 8    19th @ Boulder Creek
# 9          Settlers' Park
# Name: Return Station, dtype: object

# %%
test = pd.merge(df_full_small, elev, on = 'NAME')

# %%
test = test.rename(columns = {'e' : 'elev_start'})

# %%
df_full_small=df_full_small.rename(columns = {'Return Station':'NAME_end'})

# %%
df_full_small.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation'],
#       dtype='object')

# %%
elev.columns
# Out:
# Index(['Unnamed: 0', 'GID', 'STATION_ID', 'NAME', 'ADDRESS', 'LAT', 'LON',
#        'SOURCE', 'geometry', 'e'],
#       dtype='object')

# %%
test = pd.merge(test, elev_small2, on = 'NAME_end')

# %%
elev_small2.columns
# Out:
# Index(['NAME', 'elev_end', 'NAME_end'], dtype='object')

# %%
elev_small2 = elev_small2.rename(columns = {'e': 'elev_end'})

# %%
test.columns
# Out:
# Index(['Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME_x', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry',
# ...

# %%
test.columns
# Out:
# Index(['Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry',
#        'elev_start'],
# ...

# %% [markdown]
# ## Joining modeling dataset and elevation

# %%
elev_small.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-bd64e6909b9a> in <module>()
# ----> 1 elev_small.columns
#
# NameError: name 'elev_small' is not defined

# %%
elev_small2.columns
# Out:
# Index(['NAME', 'elev_end', 'NAME_end'], dtype='object')

# %%
df_full.shape
# Out:
# (376210, 37)

# %%
df_full = df_full.rename(columns = {'Return Station':'NAME_end'})

# %%
df_full = df_full.rename(columns = {'Checkout Station (Station Information)':'NAME'})

# %%
df_full = pd.merge(df_full, elev, on = 'NAME')

# %%
df_full = pd.merge(df_full, elev_small2, on = 'NAME_end')

# %%
df_full.columns
# Out:
# Index(['Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME_x', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry', 'e',
#        'NAME_y', 'elev_end'],
# ...

# %%
df_full.head()
# Out:
#    Unnamed: 0_x  Unnamed: 0.1  Bike Number  \
# 0             0             1          206
# 1            40            79          973
# 2           318           583          616
# 3           465           836          821
# 4           542           974          736
#
#    COUNT([Checkout Station])+COUNT([Return Station]) Checkout Date  \
# 0                                                  2       1/22/17
# 1                                                  2       5/17/17
# 2                                                  2       7/31/17
# 3                                                  2        9/4/16
# 4                                                  2       2/12/17
#
#   Checkout Day of Week        NAME_x  Checkout Station Latitude1  \
# 0               Sunday  11th & Pearl                   40.017535
# 1            Wednesday  11th & Pearl                   40.017535
# 2               Monday  11th & Pearl                   40.017535
# ...

# %%
df_full.shape
# Out:
# (355775, 48)

# %%
df_full['elev_change'] = df_full['elev_end'] - df_full['e']

# %%
df_full['net_gain'] = np.where((df_full['elev_change'] > 0), 1, 0)

# %%
df_full.to_csv('/Users/marthamorrissey/Desktop/DS_practice/df_full_elev.csv')

# %% [markdown]
# ## Joining Distance Data

# %%
dm = pd.read_csv('/Users/marthamorrissey/Desktop/DS_practice/distancematrix.csv')

# %%
dm[dm.columns[0]]
# Out:
# 0        2410-2486 Colorado Ave, Boulder, CO 80302, USA
# 1                 1505 Pearl St, Boulder, CO 80302, USA
# 2                  1911 11th St, Boulder, CO 80302, USA
# 3             2082-2098 13th St, Boulder, CO 80302, USA
# 4          3080 Center Green Dr, Boulder, CO 80301, USA
# 5             1021 Arapahoe Ave, Boulder, CO 80302, USA
# 6            2600-2710 Pearl St, Boulder, CO 80302, USA
# 7            Boulder Creek Path, Boulder, CO 80302, USA
# 8         3457-3491 Mitchell Ln, Boulder, CO 80301, USA
# 9               1235 Alpine Ave, Boulder, CO 80304, USA
# 10                 1320 19th St, Boulder, CO 80302, USA
# 11                 1600 28th St, Boulder, CO 80301, USA
# 12            2525 Arapahoe Ave, Boulder, CO 80302, USA
# 13             1870-1896 6th St, Boulder, CO 80302, USA
# 14             1401-1443 CO-119, Boulder, CO 80302, USA
# 15                 3385 30th St, Boulder, CO 80301, USA
# 16                3150 Broadway, Boulder, CO 80304, USA
# ...

# %%
addresses = dm[dm.columns[0]]

# %%
new_index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-500d6be2f21d> in <module>()
# ----> 1 new_index
#
# NameError: name 'new_index' is not defined

# %%
elev
# Out:
#     Unnamed: 0  GID           STATION_ID                             NAME  \
# 0            0   88  bcycle_boulder_1855                Folsom & Colorado
# 1            1   89  bcycle_boulder_1858                     15th & Pearl
# 2            2   90  bcycle_boulder_1859                     11th & Pearl
# 3            3   91  bcycle_boulder_1860                    13th & Spruce
# 4            4   92  bcycle_boulder_1861                UCAR Center Green
# 5            5   93  bcycle_boulder_1866               Library @ Arapahoe
# 6            6   94  bcycle_boulder_1867                     26th @ Pearl
# 7            7   95  bcycle_boulder_1869               Municipal Building
# 8            8   96  bcycle_boulder_1870               UCAR Mitchell Lane
# 9            9   97  bcycle_boulder_1871                Broadway & Alpine
# 10          10   98  bcycle_boulder_1872             19th @ Boulder Creek
# 11          11   99  bcycle_boulder_1873        Twenty Ninth Street South
# ...

# %%
new_index = elev['NAME']

# %%
dm.index = new_index

# %%
dm
# Out:
#                                                                         Unnamed: 0  \
# NAME
# Folsom & Colorado                   2410-2486 Colorado Ave, Boulder, CO 80302, USA
# 15th & Pearl                                 1505 Pearl St, Boulder, CO 80302, USA
# 11th & Pearl                                  1911 11th St, Boulder, CO 80302, USA
# 13th & Spruce                            2082-2098 13th St, Boulder, CO 80302, USA
# UCAR Center Green                     3080 Center Green Dr, Boulder, CO 80301, USA
# Library @ Arapahoe                       1021 Arapahoe Ave, Boulder, CO 80302, USA
# 26th @ Pearl                            2600-2710 Pearl St, Boulder, CO 80302, USA
# Municipal Building                      Boulder Creek Path, Boulder, CO 80302, USA
# UCAR Mitchell Lane                   3457-3491 Mitchell Ln, Boulder, CO 80301, USA
# Broadway & Alpine                          1235 Alpine Ave, Boulder, CO 80304, USA
# ...

# %%
c_list = dm.columns.get_values().tolist()

# %%
c_list = c_list[1:]

# %%
dic = dict(zip(addresses, new_index))

# %%
dic
# Out:
# {'1000-1030 Broadway, Boulder, CO 80302, USA': 'Broadway & Euclid',
#  '101 Pearl St, Boulder, CO 80302, USA': "Settlers' Park",
#  '1021 Arapahoe Ave, Boulder, CO 80302, USA': 'Library @ Arapahoe',
#  '1201 University Ave, Boulder, CO 80302, USA': 'Broadway & University',
#  '1235 Alpine Ave, Boulder, CO 80304, USA': 'Broadway & Alpine',
#  '1263-1299 Iris Ave, Boulder, CO 80304, USA': 'Broadway & Iris',
#  '1264 College Ave, Boulder, CO 80302, USA': '13th & College',
#  '1320 19th St, Boulder, CO 80302, USA': '19th @ Boulder Creek',
#  '1400 28th St, Boulder, CO 80303, USA': '28th & Boulder Creek',
#  '1401-1443 CO-119, Boulder, CO 80302, USA': '14th & Canyon',
#  '1505 Pearl St, Boulder, CO 80302, USA': '15th & Pearl',
#  '1600 28th St, Boulder, CO 80301, USA': 'Twenty Ninth Street South',
#  '1601-1621 38th St, Boulder, CO 80303, USA': '38th & Arapahoe',
#  '1759 29th St, Boulder, CO 80301, USA': 'Twenty Ninth Street North',
# ...

# %%
new_col = [dic[x] for x in c_list]

# %%
new_col
# Out:
# ['Broadway & Euclid',
#  "Settlers' Park",
#  'Library @ Arapahoe',
#  'Broadway & University',
#  'Broadway & Alpine',
#  'Broadway & Iris',
#  '13th & College',
#  '19th @ Boulder Creek',
#  '28th & Boulder Creek',
#  '14th & Canyon',
#  '15th & Pearl',
#  'Twenty Ninth Street South',
#  '38th & Arapahoe',
#  'Twenty Ninth Street North',
#  '6th & Canyon',
#  '31st & Pearl',
#  '11th & Pearl',
#  '20th & Pearl',
#  '9th & Pearl',
#  '13th & Spruce',
#  'Pearl Place',
#  '21st & Arapahoe',
#  'Boulder Junction',
#  'Folsom & Colorado',
#  'Broadway & Baseline',
#  'Folsom & Pearl',
#  'The Village',
#  '28th & Mapleton',
#  '26th @ Pearl',
#  'Table Mesa Park-n-Ride',
#  '29th & Pearl',
#  '30th & Marine',
#  'UCAR Center Green',
#  'North Boulder Recreation Center',
#  '30th & Glenwood',
#  '30th & Diagonal Highway',
#  'UCAR Mitchell Lane',
#  '35th & Colorado',
#  '48th & Arapahoe',
#  'Gunbarrel North',
#  'Williams Village',
#  '13th & Arapahoe']

# %%
new_col.insert(0, 'Unnamed: 0_x')

# %%
new_col
# Out:
# ['Unnamed: 0_x',
#  'Broadway & Euclid',
#  "Settlers' Park",
#  'Library @ Arapahoe',
#  'Broadway & University',
#  'Broadway & Alpine',
#  'Broadway & Iris',
#  '13th & College',
#  '19th @ Boulder Creek',
#  '28th & Boulder Creek',
#  '14th & Canyon',
#  '15th & Pearl',
#  'Twenty Ninth Street South',
#  '38th & Arapahoe',
#  'Twenty Ninth Street North',
#  '6th & Canyon',
#  '31st & Pearl',
#  '11th & Pearl',
#  '20th & Pearl',
#  '9th & Pearl',
#  '13th & Spruce',
#  'Pearl Place',
#  '21st & Arapahoe',
#  'Boulder Junction',
#  'Folsom & Colorado',
#  'Broadway & Baseline',
#  'Folsom & Pearl',
#  'The Village',
#  '28th & Mapleton',
#  '26th @ Pearl',
#  'Table Mesa Park-n-Ride',
#  '29th & Pearl',
#  '30th & Marine',
#  'UCAR Center Green',
#  'North Boulder Recreation Center',
#  '30th & Glenwood',
#  '30th & Diagonal Highway',
#  'UCAR Mitchell Lane',
#  '35th & Colorado',
#  '48th & Arapahoe',
#  'Gunbarrel North',
#  'Williams Village',
#  '13th & Arapahoe']

# %%
dm.columns = new_col

# %%
dm.to_csv('/Users/marthamorrissey/Desktop/DS_practice/dm.csv')

# %%
dm.columns[1]
# Out:
# 'Broadway & Euclid'

# %%
(dm.loc[['Broadway & Euclid'], ['Broadway & Euclid']]).values[0][0]
# Out:
# 0

# %%
test = pd.read_csv('/Users/marthamorrissey/Desktop/DS_practice/df_full_elev.csv')

# %%
test_small = test.head(50)

# %%
test_small.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME_x', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry', 'e',
# ...

# %%
test_small.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1  Bike Number  \
# 0           0             0             1          206
# 1           1            40            79          973
# 2           2           318           583          616
# 3           3           465           836          821
# 4           4           542           974          736
#
#    COUNT([Checkout Station])+COUNT([Return Station]) Checkout Date  \
# 0                                                  2       1/22/17
# 1                                                  2       5/17/17
# 2                                                  2       7/31/17
# 3                                                  2        9/4/16
# 4                                                  2       2/12/17
#
#   Checkout Day of Week        NAME_x  Checkout Station Latitude1  \
# 0               Sunday  11th & Pearl                   40.017535
# 1            Wednesday  11th & Pearl                   40.017535
# ...

# %%
#Name_x, NAME_end

# %%
test_small['NAME_x'][1]
# Out:
# '11th & Pearl'

# %%
test_small['NAME_end'][0]
# Out:
# '9th & Pearl'

# %%
dm.loc[[test_small['NAME_x'][1]], [test_small['NAME_end'][1]]].values[0][0]
# Out:
# 263

# %%
Municipal Building

# %%
d_list = []
for i in range(50):
    x = dm.loc[[test_small['NAME_x'][i]], [test_small['NAME_end'][i]]].values[0][0]
    d_list.append(x)

# %%
d_list
# Out:
# [263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263,
#  263]

# %%
test.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME_x', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry', 'e',
# ...

# %%
test.shape
# Out:
# (355775, 51)

# %%
len(test['NAME_x'].unique())
# Out:
# 43

# %%
len(test['NAME_end'].unique())
# Out:
# 43

# %%
test['NAME_x']

# %%
test.shape
# Out:
# (355775, 51)

# %%
#drop rows with municipal building

# %%
dframe = dframe[dframe["A"] != 'a']

# %%
test_d = test[test["NAME_end"] != 'Municipal Building']

# %%
test_d.shape
# Out:
# (337003, 51)

# %%
test_d2 = test_d[test_d['NAME_x'] != 'Municipal Building']

# %%
test_d2.shape
# Out:
# (323251, 51)

# %%
337961 < 355775
# Out:
# True

# %%
test_d2.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0_x', 'Unnamed: 0.1', 'Bike Number',
#        'COUNT([Checkout Station])+COUNT([Return Station])', 'Checkout Date',
#        'Checkout Day of Week', 'NAME_x', 'Checkout Station Latitude1',
#        'Checkout Station Longitude1', 'Checkout Station', 'Checkout Time',
#        'Entry Pass Type', 'Installation Date', 'Most Recent Number of Docks',
#        'Number of Records', 'Power Source', 'Removal Date', 'Return Date',
#        'Return Day of Week', 'Return Station (Station Information)',
#        'Return Station Latitude', 'Return Station Longitude', 'NAME_end',
#        'Return Time', 'Rider Home System', 'Rider or Operator Number',
#        'Trip Duration (Minutes)', 'ot', 'weekend', 'Return dt', 'Return hour',
#        'Checkout dt', 'Checkout hour', 'am_commute_hrs', 'pm_commute_hrs',
#        'encoded_cstation', 'encoded_rstation', 'Unnamed: 0_y', 'GID',
#        'STATION_ID', 'ADDRESS', 'LAT', 'LON', 'SOURCE', 'geometry', 'e',
# ...

# %%
test_d2.index = range(len(test_d2))

# %%
d_list = []
for i in range(323251):
    x = dm.loc[[test_d2['NAME_x'][i]], [test_d2['NAME_end'][i]]].values[0][0]
    d_list.append(x)

# %%
x
# Out:
# 943

# %%
len(d_list)
# Out:
# 323251

# %%
test_d2['o_d_dist'] = d_list
# Out:
# //anaconda/envs/snakee/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
test_d2.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x  Unnamed: 0.1  Bike Number  \
# 0           0             0             1          206
# 1           1            40            79          973
# 2           2           318           583          616
# 3           3           465           836          821
# 4           4           542           974          736
#
#    COUNT([Checkout Station])+COUNT([Return Station]) Checkout Date  \
# 0                                                  2       1/22/17
# 1                                                  2       5/17/17
# 2                                                  2       7/31/17
# 3                                                  2        9/4/16
# 4                                                  2       2/12/17
#
#   Checkout Day of Week        NAME_x  Checkout Station Latitude1  \
# 0               Sunday  11th & Pearl                   40.017535
# 1            Wednesday  11th & Pearl                   40.017535
# ...

# %%
test_d2.to_csv('/Users/marthamorrissey/Desktop/DS_practice/df_elev_dist.csv')

# %%
len(test_d2['o_d_dist'].unique())
# Out:
# 1377
